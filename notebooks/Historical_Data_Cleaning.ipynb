# %% [markdown]
# # Historical Data Cleaning

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as plx

# %% [markdown]
# ## Load Dataset

# %%
trades = pd.read_csv(
   '../data/raw/historical_data/historical_data.csv',
    parse_dates=["Timestamp IST"],
    dayfirst=True,
    low_memory=False
)

# %% [markdown]
# ## Standardize the columns

# %%
trades.columns = (
    trades.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace(r"[^\w\s]", "", regex=True)
)

# %% [markdown]
# ## Strip whitespace in string columns

# %%
for col in trades.select_dtypes(include="object"):
    trades[col] = trades[col].astype(str).str.strip()

# %%
trades.head()
# Out:
#                                       account  coin  execution_price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    size_tokens  size_usd side       timestamp_ist  start_position direction  \
# 0       986.87   7872.16  BUY 2024-12-02 22:50:00        0.000000       Buy
# 1        16.00    127.68  BUY 2024-12-02 22:50:00      986.524596       Buy
# 2       144.09   1150.63  BUY 2024-12-02 22:50:00     1002.518996       Buy
# 3       142.98   1142.04  BUY 2024-12-02 22:50:00     1146.558564       Buy
# 4         8.73     69.75  BUY 2024-12-02 22:50:00     1289.488521       Buy
#
#    closed_pnl                                   transaction_hash     order_id  \
# 0         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 1         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 2         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 3         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
# 4         0.0  0xec09451986a1874e3a980418412fcd0201f500c95bac...  52017706630
#
#    crossed       fee      trade_id     timestamp
# 0     True  0.345404  8.950000e+14  1.730000e+12
# 1     True  0.005600  4.430000e+14  1.730000e+12
# 2     True  0.050431  6.600000e+14  1.730000e+12
# 3     True  0.050043  1.080000e+15  1.730000e+12
# 4     True  0.003055  1.050000e+15  1.730000e+12

# %% [markdown]
# ## Check for Duplicate values

# %%
for col in trades.columns:
    print(f"{col} : {trades[col].duplicated().sum()} duplicates")
# Out:
# account : 211192 duplicates
# coin : 210978 duplicates
# execution_price : 151062 duplicates
# size_tokens : 151920 duplicates
# size_usd : 92731 duplicates
# side : 211222 duplicates
# timestamp_ist : 183247 duplicates
# start_position : 14301 duplicates
# direction : 211212 duplicates
# closed_pnl : 120504 duplicates
# transaction_hash : 110040 duplicates
# order_id : 160669 duplicates
# crossed : 211222 duplicates
# fee : 72422 duplicates
# trade_id : 208414 duplicates
# timestamp : 211217 duplicates

# %% [markdown]
# ## Check for Unique values

# %%
for col in trades.columns:
    print(f"{col} : {trades[col].nunique()} uniques")
# Out:
# account : 32 uniques
# coin : 246 uniques
# execution_price : 60162 uniques
# size_tokens : 59304 uniques
# size_usd : 118493 uniques
# side : 2 uniques
# timestamp_ist : 27977 uniques
# start_position : 196923 uniques
# direction : 12 uniques
# closed_pnl : 90720 uniques
# transaction_hash : 101184 uniques
# order_id : 50555 uniques
# crossed : 2 uniques
# fee : 138802 uniques
# trade_id : 2810 uniques
# timestamp : 7 uniques

# %%
trades.shape
# Out:
# (211224, 16)

# %% [markdown]
# ## Convert IST → UTC

# %%
trades = trades.rename(columns={"timestamp_ist": "timestamp_local"})
trades["timestamp_local"] = pd.to_datetime(trades["timestamp_local"], dayfirst=True)
trades["timestamp_local"] = trades["timestamp_local"].dt.tz_localize("Asia/Kolkata")
trades["timestamp_utc"] = trades["timestamp_local"].dt.tz_convert("UTC")

# %% [markdown]
# ## Time features

# %%
trades["date"] = trades["timestamp_utc"].dt.date
trades["hour"] = trades["timestamp_utc"].dt.hour
trades["weekday"] = trades["timestamp_utc"].dt.weekday
trades["week"] = trades["timestamp_utc"].dt.isocalendar().week
trades["year"] = trades["timestamp_utc"].dt.year
trades["is_weekend"] = trades["weekday"].isin([5, 6]).astype(int)

# %% [markdown]
# ## Numeric features

# %%
trades["win"] = (trades["closed_pnl"] > 0).astype(int)
trades["abs_size_tokens"] = trades["size_tokens"].abs()
trades["abs_size_usd"] = trades["size_usd"].abs()
trades["roi"] = np.where(
    trades["size_usd"] != 0,
    trades["closed_pnl"] / trades["size_usd"],
    0
)

# %%
trades
# Out:
#                                            account      coin  execution_price  \
# 0       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9769
# 1       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9800
# 2       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9855
# 3       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9874
# 4       0xae5eacaf9c6b9111fd53034a602c192a04e082ed      @107           7.9894
# ...                                            ...       ...              ...
# 211219  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211220  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211221  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211222  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
# 211223  0x72743ae2822edd658c0c50608fd7c5c501b2afbd  FARTCOIN           1.1010
#
#         size_tokens  size_usd  side           timestamp_local  start_position  \
# 0            986.87   7872.16   BUY 2024-12-02 22:50:00+05:30        0.000000
# 1             16.00    127.68   BUY 2024-12-02 22:50:00+05:30      986.524596
# 2            144.09   1150.63   BUY 2024-12-02 22:50:00+05:30     1002.518996
# 3            142.98   1142.04   BUY 2024-12-02 22:50:00+05:30     1146.558564
# 4              8.73     69.75   BUY 2024-12-02 22:50:00+05:30     1289.488521
# ...             ...       ...   ...                       ...             ...
# 211219       382.20    420.80  SELL 2025-04-25 15:35:00+05:30     7546.600000
# 211220      2124.10   2338.63  SELL 2025-04-25 15:35:00+05:30     7164.400000
# 211221       423.40    466.16  SELL 2025-04-25 15:35:00+05:30     5040.300000
# 211222      3599.80   3963.38  SELL 2025-04-25 15:35:00+05:30     4616.900000
# 211223      1017.10   1119.83  SELL 2025-04-25 15:35:00+05:30     1017.100000
#
#          direction  closed_pnl  ...        date  hour  weekday  week  year  \
# 0              Buy      0.0000  ...  2024-12-02    17        0    49  2024
# 1              Buy      0.0000  ...  2024-12-02    17        0    49  2024
# 2              Buy      0.0000  ...  2024-12-02    17        0    49  2024
# 3              Buy      0.0000  ...  2024-12-02    17        0    49  2024
# 4              Buy      0.0000  ...  2024-12-02    17        0    49  2024
# ...            ...         ...  ...         ...   ...      ...   ...   ...
# 211219  Close Long    -20.2566  ...  2025-04-25    10        4    17  2025
# 211220  Close Long   -112.5773  ...  2025-04-25    10        4    17  2025
# 211221  Close Long    -22.4402  ...  2025-04-25    10        4    17  2025
# 211222  Close Long   -190.7894  ...  2025-04-25    10        4    17  2025
# 211223  Close Long    -53.9063  ...  2025-04-25    10        4    17  2025
#
#         is_weekend win abs_size_tokens  abs_size_usd       roi
# 0                0   0          986.87       7872.16  0.000000
# 1                0   0           16.00        127.68  0.000000
# 2                0   0          144.09       1150.63  0.000000
# 3                0   0          142.98       1142.04  0.000000
# 4                0   0            8.73         69.75  0.000000
# ...            ...  ..             ...           ...       ...
# 211219           0   0          382.20        420.80 -0.048138
# 211220           0   0         2124.10       2338.63 -0.048138
# 211221           0   0          423.40        466.16 -0.048138
# 211222           0   0         3599.80       3963.38 -0.048138
# 211223           0   0         1017.10       1119.83 -0.048138
#
# [211224 rows x 27 columns]

# %% [markdown]
# # Save the cleaned dataset

# %%
trades.to_csv('../data/preprocessed/historical_data/cleaned_historical_data.csv', index=False)
